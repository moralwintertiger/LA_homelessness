# %% [markdown]
# # This notebook will explore data related to the LAHSA reports on LA homelessness in 2018.
#
# Reports are publically available at: https://www.lahsa.org/news?article=557-2019-greater-los-angeles-homeless-count-results
#
# Note that data are spread between many reports, each of which is a PDF. There are also census-tract data in csv format, but this csv was generated by a four-day survey and LAHSA notes that the data will not add up to totals seen in other reports.
#
# I'll intake a full report for LA, as well as district-specific reports. Each report will be cleaned up to be used for downstream analysis. Throughout, I'll use pandas to work with dataframes, tabula to convert pdfs to dataframes, and requests to fetch data.
#
# Some of the items to dig into: demographics, relation of an area's wealth/rent rates to homelessness, death rates (if data exist).

# %%
###Data files (examples):

# https://www.lahsa.org/documents?id=3444-2019-greater-los-angeles-homeless-count-council-district-4.pdf
# https://www.lahsa.org/documents?id=3441-2019-greater-los-angeles-homeless-count-council-district-1.pdf

# There are 15 such files, each ending w/ council-district-n.pdf

# %% [markdown]
# ## First off, let's streamline the intake and digestion of all these PDFs
#
# 1. build a list of URLs
# 2. use the requests package to get the data from these URLs
# 3. use the tabula package to read data from the URLs into pandas dataframes

# %%
import requests
import pandas as pd
import tabula
import matplotlib.pyplot as plt

# %%
##note that the URLs listed above are the page URLs that include download links for our files. Here's what the base url
##for a downloadable file looks like:

example_url = "https://www.lahsa.org/item.ashx?id=3441-2019-greater-los-angeles-homeless-count-council-district-1.pdf&dl=true"
base_url = "https://www.lahsa.org/item.ashx?id="
base_url_2 = "-2019-greater-los-angeles-homeless-count-council-district-"
suffix = ".pdf&dl=true"

##build a list of urls to download:
tag_list = [3441, 3442, 3443, 3444, 3445, 3446, 3447, 3649, 3449, 3450, 3451, 3452, 3453, 3454, 3455]

url_list = []
for i in range(1,16):
    url_list.append(base_url + str(tag_list[i-1]) + base_url_2 + str(i) + suffix)

url_list
# Out:
# ['https://www.lahsa.org/item.ashx?id=3441-2019-greater-los-angeles-homeless-count-council-district-1.pdf&dl=true',
#  'https://www.lahsa.org/item.ashx?id=3442-2019-greater-los-angeles-homeless-count-council-district-2.pdf&dl=true',
#  'https://www.lahsa.org/item.ashx?id=3443-2019-greater-los-angeles-homeless-count-council-district-3.pdf&dl=true',
#  'https://www.lahsa.org/item.ashx?id=3444-2019-greater-los-angeles-homeless-count-council-district-4.pdf&dl=true',
#  'https://www.lahsa.org/item.ashx?id=3445-2019-greater-los-angeles-homeless-count-council-district-5.pdf&dl=true',
#  'https://www.lahsa.org/item.ashx?id=3446-2019-greater-los-angeles-homeless-count-council-district-6.pdf&dl=true',
#  'https://www.lahsa.org/item.ashx?id=3447-2019-greater-los-angeles-homeless-count-council-district-7.pdf&dl=true',
#  'https://www.lahsa.org/item.ashx?id=3649-2019-greater-los-angeles-homeless-count-council-district-8.pdf&dl=true',
#  'https://www.lahsa.org/item.ashx?id=3449-2019-greater-los-angeles-homeless-count-council-district-9.pdf&dl=true',
#  'https://www.lahsa.org/item.ashx?id=3450-2019-greater-los-angeles-homeless-count-council-district-10.pdf&dl=true',
#  'https://www.lahsa.org/item.ashx?id=3451-2019-greater-los-angeles-homeless-count-council-district-11.pdf&dl=true',
#  'https://www.lahsa.org/item.ashx?id=3452-2019-greater-los-angeles-homeless-count-council-district-12.pdf&dl=true',
#  'https://www.lahsa.org/item.ashx?id=3453-2019-greater-los-angeles-homeless-count-council-district-13.pdf&dl=true',
#  'https://www.lahsa.org/item.ashx?id=3454-2019-greater-los-angeles-homeless-count-council-district-14.pdf&dl=true',
#  'https://www.lahsa.org/item.ashx?id=3455-2019-greater-los-angeles-homeless-count-council-district-15.pdf&dl=true']

# %%
## download one pdf as a test:

r = requests.get(example_url)
with open("pdfs/test.pdf", "wb") as code:
    code.write(r.content)

# %%
#download them all:

for i in range(len(url_list)):
    r = requests.get(url_list[i])
    with open(("pdfs/CD" + str(i+1) + ".pdf"), "wb") as code:
        code.write(r.content)

# %% [markdown]
# ## confirm that we've downloaded all our files:

# %%
# %%bash
# cd pdfs
# ls
# Out:
# CD1.pdf
# CD10.pdf
# CD11.pdf
# CD12.pdf
# CD13.pdf
# CD14.pdf
# CD15.pdf
# CD2.pdf
# CD3.pdf
# CD4.pdf
# CD5.pdf
# CD6.pdf
# CD7.pdf
# CD8.pdf
# CD9.pdf
# LA_City.pdf

# %% [markdown]
# ## Use tabula to read in our dataframes.
#
# Note that for tabula to work, you'll need to install a JDK (downloadable from Oracle, but you'll need to set up a developer's account with them.

# %%
from tabula import read_pdf

cd4_df = read_pdf("pdfs/CD4.pdf", multiple_tables=True)

# %%
#explore the data. Note that the dataframes are a bit of a mess as they're read in. Here I'll split them into two 
#separate dataframes and clean them separately:

la_df = read_pdf("pdfs/LA_City.pdf", multiple_tables=True)

# %%
totals, demographics = la_df[0], la_df[1]
demographics
# Out:
#                                  Population Sheltered Unsheltered   Total  \
# 0                                    Gender       NaN         NaN     NaN
# 1                                      Male     4,697      19,663  24,360
# 2                                    Female     4,125       6,720  10,845
# 3                               Transgender       102         708     810
# 4                     Gender Non‐Conforming        20         130     150
# 5                            Race/Ethnicity       NaN         NaN     NaN
# 6            American Indian/ Alaska Native        42         488     530
# 7                                     Asian        53         246     299
# 8                    Black/African American     4,716       8,913  13,629
# 9                          Hispanic/ Latino     2,864       9,539  12,403
# 10  Native Hawaiian/ Other Pacific Islander        36          64     100
# 11                                    White     1,078       7,145   8,223
# 12                       Multi‐Racial/Other       155         826     981
# 13                                      Age       NaN         NaN     NaN
# 14                                 Under 18     2,627         678   3,305
# 15                                  18 ‐ 24       925       1,347   2,272
# 16                                  25 ‐ 54     3,981      17,807  21,788
# 17                                  55 ‐ 61       809       4,845   5,654
# 18                              62 and Over       602       2,544   3,146
# 19                       Sexual Orientation       NaN         NaN     NaN
# 20                                 Straight     7,867      24,620  32,487
# 21                           Gay or Lesbian       397       1,004   1,401
# 22                                 Bisexual       232       1,206   1,438
# 23        Sexual Orientation Non‐Conforming       448         391     839
#
#    Prevalence Percent_Change
# 0         NaN            NaN
# 1         67%       +17% Yes
# 2         30%       +13% Yes
# 3          2%        +18% No
# 4        0.4%        +33% No
# 5         NaN            NaN
# 6          1%        +64% No
# 7          1%        ‐15% No
# 8         38%        +11% No
# 9         34%        +15% No
# 10       0.3%        +30% No
# 11        23%       +18% Yes
# 12         3%       +94% Yes
# 13        NaN            NaN
# 14         9%        +9% Yes
# 15         6%        +11% No
# 16        60%       +18% Yes
# 17        16%        +19% No
# 18         9%         +5% No
# 19        NaN            NaN
# 20        90%     3N/A 3 N/A
# 21         4%     3N/A 3 N/A
# 22         4%     3N/A 3 N/A
# 23       2.3%     3N/A 3 N/A

# %%
#clean up demographics page:

column_list = ["Population", "Sheltered", "Unsheltered", "Total", "Prevalence", "Percent_Change"]
demographics.columns = column_list
demographics = demographics.dropna()
demographics = demographics.set_index('Population')
demographics['Percent_Change'] = [demographics['Percent_Change'][i].split()[0] for i in range(len(demographics))]

# %%
demographics
# Out:
#                                         Sheltered Unsheltered   Total  \
# Population
# Male                                        4,697      19,663  24,360
# Female                                      4,125       6,720  10,845
# Transgender                                   102         708     810
# Gender Non‐Conforming                          20         130     150
# American Indian/ Alaska Native                 42         488     530
# Asian                                          53         246     299
# Black/African American                      4,716       8,913  13,629
# Hispanic/ Latino                            2,864       9,539  12,403
# Native Hawaiian/ Other Pacific Islander        36          64     100
# White                                       1,078       7,145   8,223
# Multi‐Racial/Other                            155         826     981
# Under 18                                    2,627         678   3,305
# 18 ‐ 24                                       925       1,347   2,272
# 25 ‐ 54                                     3,981      17,807  21,788
# 55 ‐ 61                                       809       4,845   5,654
# 62 and Over                                   602       2,544   3,146
# Straight                                    7,867      24,620  32,487
# Gay or Lesbian                                397       1,004   1,401
# Bisexual                                      232       1,206   1,438
# Sexual Orientation Non‐Conforming             448         391     839
#
#                                         Prevalence Percent_Change
# Population
# Male                                           67%           +17%
# Female                                         30%           +13%
# Transgender                                     2%           +18%
# Gender Non‐Conforming                         0.4%           +33%
# American Indian/ Alaska Native                  1%           +64%
# Asian                                           1%           ‐15%
# Black/African American                         38%           +11%
# Hispanic/ Latino                               34%           +15%
# Native Hawaiian/ Other Pacific Islander       0.3%           +30%
# White                                          23%           +18%
# Multi‐Racial/Other                              3%           +94%
# Under 18                                        9%            +9%
# 18 ‐ 24                                         6%           +11%
# 25 ‐ 54                                        60%           +18%
# 55 ‐ 61                                        16%           +19%
# 62 and Over                                     9%            +5%
# Straight                                       90%           3N/A
# Gay or Lesbian                                  4%           3N/A
# Bisexual                                        4%           3N/A
# Sexual Orientation Non‐Conforming             2.3%           3N/A

# %%
###build our totals dataframe:

totals = totals.dropna().reset_index()
totals['Population'] = [totals[0][i] for i in range(len(totals))]
totals['Sheltered'] = [totals[1][i].split()[0] for i in range(len(totals))]
totals['Unsheltered'] = [totals[1][i].split()[1] for i in range(len(totals))]
totals['Total'] = [totals[1][i].split()[2] for i in range(len(totals))]
totals['Prevalence'] = [totals[1][i].split()[3] for i in range(len(totals))]
totals['Percent_Change'] = [totals[1][i].split()[4] for i in range(len(totals))]
totals = totals.drop(['index', 0, 1, 2], axis=1)
totals = totals.set_index('Population')

# %%
totals
# Out:
#                                                  Sheltered Unsheltered  \
# Population
# All Persons                                          8,944      27,221
# Individuals (Those not in family units)              4,636      25,993
# Adults (Over 24)                                     4,040      24,756
# Transition Age Youth (18‐24)                           596       1,237
# Chronically Homeless                                   967       9,117
# Veterans                                               306       1,859
# Unaccompanied Minors (Under 18)                         21          33
# Family Members (Those in family units)               4,287       1,195
# Adult Family Members (Over 24 Head of Household)     3,777       1,010
# Young Family Members (18‐24 Head of Household)         510         185
# Children in Families (Under 18)                      2,606         645
# Chronically Homeless                                   265         131
# Veterans                                                10          22
# All Veterans                                           316       1,881
# Chronically Homeless Veterans                           39         693
# Individuals (Those not in family units)                967       9,117
# Family Members (Those in family units)                 265         131
# Total Chronically Homeless Persons                   1,232       9,248
#
#                                                    Total Prevalence  \
# Population
# All Persons                                       36,165       100%
# Individuals (Those not in family units)           30,629        85%
# Adults (Over 24)                                  28,796        80%
# Transition Age Youth (18‐24)                       1,833         5%
# Chronically Homeless                              10,084        28%
# Veterans                                           2,165         6%
# Unaccompanied Minors (Under 18)                       54       0.1%
# Family Members (Those in family units)             5,482        15%
# Adult Family Members (Over 24 Head of Household)   4,787        13%
# Young Family Members (18‐24 Head of Household)       695         2%
# Children in Families (Under 18)                    3,251         9%
# Chronically Homeless                                 396         1%
# Veterans                                              32       0.1%
# All Veterans                                       2,197         6%
# Chronically Homeless Veterans                        732         2%
# Individuals (Those not in family units)           10,084        28%
# Family Members (Those in family units)               396         1%
# Total Chronically Homeless Persons                10,480        29%
#
#                                                  Percent_Change
# Population
# All Persons                                                +16%
# Individuals (Those not in family units)                    +17%
# Adults (Over 24)                                           +17%
# Transition Age Youth (18‐24)                               +17%
# Chronically Homeless                                       +21%
# Veterans                                                    +6%
# Unaccompanied Minors (Under 18)                             ‐7%
# Family Members (Those in family units)                    +7.3%
# Adult Family Members (Over 24 Head of Household)            +6%
# Young Family Members (18‐24 Head of Household)             +20%
# Children in Families (Under 18)                            +10%
# Chronically Homeless                                       +42%
# Veterans                                                  +220%
# All Veterans                                                +7%
# Chronically Homeless Veterans                              ‐19%
# Individuals (Those not in family units)                    +21%
# Family Members (Those in family units)                     +42%
# Total Chronically Homeless Persons                         +21%

# %%
###generalize this cleaning up so that we can read in council-district-specific datasets:

# %%
cd4_df = read_pdf("pdfs/CD4.pdf", multiple_tables=True)

# %%
def clean_df(dataframe):
    
    
    '''cleans up dataframes imported from tabula. As an input it takes a tabula-returned df. As an output it provides 
    a demographic table and a totals table with columns=population, sheltered, unsheltered, total, prevalence (
    as a proportion of total), percent change (in this case, since 2018)'''
    
    totals, demographics = dataframe[0], dataframe[1]
    totals = totals.dropna().reset_index()
    totals['Population'] = [totals[0][i] for i in range(len(totals))]
    totals['Sheltered'] = [totals[1][i].split()[0] for i in range(len(totals))]
    totals['Unsheltered'] = [totals[1][i].split()[1] for i in range(len(totals))]
    totals['Total'] = [totals[1][i].split()[2] for i in range(len(totals))]
    totals['Prevalence'] = [totals[1][i].split()[3] for i in range(len(totals))]
    totals['Percent_Change'] = [totals[1][i].split()[4] for i in range(len(totals))]
    totals = totals.drop(['index', 0, 1, 2], axis=1)
    totals = totals.set_index('Population')
    
    demographics = demographics.drop([6], axis=1)
    column_list = ["Population", "Sheltered", "Unsheltered", "Total", "Prevalence", "Percent_Change"]
    demographics.columns = column_list
    demographics = demographics.dropna()
    demographics = demographics.set_index('Population')
    demographics['Percent_Change'] = [demographics['Percent_Change'][i].split()[0] for i in range(len(demographics))]
    
    return totals, demographics

# %%
cd4_totals, cd4_demographics = cd4_df[0], cd4_df[1]
column_list = ["Population", "Sheltered", "Unsheltered", "Total", "Prevalence", "Percent_Change"]

# %%
cd4_demographics = cd4_demographics.drop([6], axis=1)
cd4_demographics
# Out:
#                                           0    1    2    3     4      5
# 0                                    Gender  NaN  NaN  NaN   NaN    NaN
# 1                                      Male   15  847  862   73%   +64%
# 2                                    Female   15  250  265   22%   +37%
# 3                               Transgender   16   37   53    4%   +10%
# 4                     Gender Non-Conforming    5    2    7  0.6%   -30%
# 5                            Race/Ethnicity  NaN  NaN  NaN   NaN    NaN
# 6            American Indian/ Alaska Native    0   13   13    1%   -28%
# 7                                     Asian    2   23   25    2%   +47%
# 8                    Black/African American   30  327  357   30%   +48%
# 9                          Hispanic/ Latino    9  457  466   39%  +111%
# 10  Native Hawaiian/ Other Pacific Islander    0    1    1  0.1%   N/A*
# 11                                    White   10  286  296   25%   +13%
# 12                       Multi-Racial/Other    0   29   29    2%   +53%
# 13                                      Age  NaN  NaN  NaN   NaN    NaN
# 14                                 Under 18    0    5    5    0%   -82%
# 15                                  18 - 24   22  109  131   11%    -1%
# 16                                  25 - 54   18  867  885   75%   +90%
# 17                                  55 - 61    7   95  102    9%   +24%
# 18                              62 and Over    4   60   64    5%    -7%
# 19                       Sexual Orientation  NaN  NaN  NaN   NaN    NaN
# 20                                 Straight   16  968  984   83%   N/A3
# 21                           Gay or Lesbian   19   99  118   10%   N/A3
# 22                                 Bisexual   11   35   46    4%   N/A3
# 23        Sexual Orientation Non-Conforming    5   34   39  3.3%   N/A3

# %%
column_list = ["Population", "Sheltered", "Unsheltered", "Total", "Prevalence", "Percent_Change"]
demographics.columns = column_list
demographics = demographics.dropna()
demographics = demographics.set_index('Population')
demographics['Percent_Change'] = [demographics['Percent_Change'][i].split()[0] for i in range(len(demographics))]
# Out:
#     index                                        0  \
# 0       6                              All Persons
# 1       8  Individuals (Those not in family units)
# 2       9                         Adults (Over 24)
# 3      10             Transition Age Youth (18-24)
# 4      11                     Chronically Homeless
# 5      12                                 Veterans
# 6      13          Unaccompanied Minors (Under 18)
# 7      14   Family Members (Those in family units)
# 8      15                     Adult Family Members
# 9      16                     Young Family Members
# 10     17                     Children in Families
# 11     18                     Chronically Homeless
# 12     19                                 Veterans
# 13     21                             All Veterans
# 14     22            Chronically Homeless Veterans
# 15     24  Individuals (Those not in family units)
# 16     25   Family Members (Those in family units)
# 17     26       Total Chronically Homeless Persons
#
#                                             1    2  \
# 0                    51 1,136 1,187 100% +53%  Yes
# 1                     51 1,128 1,179 99% +62%  Yes
# 2                     29 1,020 1,049 88% +75%   No
# 3                          22 108 130 11% +1%   No
# 4                         15 270 285 24% +28%   No
# 5                             0 25 25 2% -54%   No
# 6                             0 1 1 0.1% N/A*   No
# 7                             0 7 7 1% -85.4%  Yes
# 8   (Over 24 Head of Household) 0 5 5 0% -89%   No
# 9     (18-24 Head of Household) 0 2 2 0% -50%   No
# 10                   (Under 18) 0 4 4 0% -86%  Yes
# 11                              0 0 0 0% N/A*   No
# 12                           0 0 0 0.0% -100%   No
# 13                            0 25 25 2% -55%   No
# 14                              0 9 9 1% -53%   No
# 15                        15 270 285 24% +28%   No
# 16                              0 0 0 0% N/A*   No
# 17                        15 270 285 24% +28%   No
#
#                                  Population Sheltered Unsheltered
# 0                               All Persons        51       1,136
# 1   Individuals (Those not in family units)        51       1,128
# 2                          Adults (Over 24)        29       1,020
# 3              Transition Age Youth (18-24)        22         108
# 4                      Chronically Homeless        15         270
# 5                                  Veterans         0          25
# 6           Unaccompanied Minors (Under 18)         0           1
# 7    Family Members (Those in family units)         0           7
# 8                      Adult Family Members     (Over          24
# 9                      Young Family Members    (18-24        Head
# 10                     Children in Families    (Under         18)
# 11                     Chronically Homeless         0           0
# 12                                 Veterans         0           0
# 13                             All Veterans         0          25
# 14            Chronically Homeless Veterans         0           9
# 15  Individuals (Those not in family units)        15         270
# 16   Family Members (Those in family units)         0           0
# 17       Total Chronically Homeless Persons        15         270

# %%
cd4_totals, cd4_demographics = clean_df(cd4_df)

# %%
cd4_demographics
# Out:
#                                         Sheltered Unsheltered Total  \
# Population
# Male                                           15         847   862
# Female                                         15         250   265
# Transgender                                    16          37    53
# Gender Non-Conforming                           5           2     7
# American Indian/ Alaska Native                  0          13    13
# Asian                                           2          23    25
# Black/African American                         30         327   357
# Hispanic/ Latino                                9         457   466
# Native Hawaiian/ Other Pacific Islander         0           1     1
# White                                          10         286   296
# Multi-Racial/Other                              0          29    29
# Under 18                                        0           5     5
# 18 - 24                                        22         109   131
# 25 - 54                                        18         867   885
# 55 - 61                                         7          95   102
# 62 and Over                                     4          60    64
# Straight                                       16         968   984
# Gay or Lesbian                                 19          99   118
# Bisexual                                       11          35    46
# Sexual Orientation Non-Conforming               5          34    39
#
#                                         Prevalence Percent_Change
# Population
# Male                                           73%           +64%
# Female                                         22%           +37%
# Transgender                                     4%           +10%
# Gender Non-Conforming                         0.6%           -30%
# American Indian/ Alaska Native                  1%           -28%
# Asian                                           2%           +47%
# Black/African American                         30%           +48%
# Hispanic/ Latino                               39%          +111%
# Native Hawaiian/ Other Pacific Islander       0.1%           N/A*
# White                                          25%           +13%
# Multi-Racial/Other                              2%           +53%
# Under 18                                        0%           -82%
# 18 - 24                                        11%            -1%
# 25 - 54                                        75%           +90%
# 55 - 61                                         9%           +24%
# 62 and Over                                     5%            -7%
# Straight                                       83%           N/A3
# Gay or Lesbian                                 10%           N/A3
# Bisexual                                        4%           N/A3
# Sexual Orientation Non-Conforming             3.3%           N/A3

# %%
def retrieve_clean_df(council_district):
    
    
    '''cleans up dataframes imported from tabula. As an input it takes a tabula-returned df. As an output it provides 
    a demographic table and a totals table with columns=population, sheltered, unsheltered, total, prevalence (
    as a proportion of total), percent change (in this case, since 2018)'''
    
    #cd4_df = read_pdf("pdfs/CD4.pdf", multiple_tables=True)
    
    file_name = "pdfs/" + str(council_district) + ".pdf"
    dataframe = read_pdf(file_name, multiple_tables=True)
    
    totals, demographics = dataframe[0], dataframe[1]
    totals = totals.dropna().reset_index()
    totals['Population'] = [totals[0][i] for i in range(len(totals))]
    totals['Sheltered'] = [totals[1][i].split()[0] for i in range(len(totals))]
    totals['Unsheltered'] = [totals[1][i].split()[1] for i in range(len(totals))]
    totals['Total'] = [totals[1][i].split()[2] for i in range(len(totals))]
    totals['Prevalence'] = [totals[1][i].split()[3] for i in range(len(totals))]
    totals['Percent_Change'] = [totals[1][i].split()[4] for i in range(len(totals))]
    totals = totals.drop(['index', 0, 1, 2], axis=1)
    totals = totals.set_index('Population')
    
    demographics = demographics.drop([6], axis=1)
    column_list = ["Population", "Sheltered", "Unsheltered", "Total", "Prevalence", "Percent_Change"]
    demographics.columns = column_list
    demographics = demographics.dropna()
    demographics = demographics.set_index('Population')
    demographics['Percent_Change'] = [demographics['Percent_Change'][i].split()[0] for i in range(len(demographics))]
    
    return totals, demographics

# %%
cd7_totals, cd7_demographics = retrieve_clean_df("CD7")

# %%
cd7_demographics
# Out:
#                                         Sheltered Unsheltered Total  \
# Population
# Male                                          160         531   691
# Female                                         88         143   231
# Transgender                                     4           3     7
# Gender Non-Conforming                           2           0     2
# American Indian/ Alaska Native                  0           0     0
# Asian                                           3           0     3
# Black/African American                         88          69   157
# Hispanic/ Latino                               95         404   499
# Native Hawaiian/ Other Pacific Islander         0           0     0
# White                                          64         154   218
# Multi-Racial/Other                              4          50    54
# Under 18                                       40           0    40
# 18 - 24                                        27          34    61
# 25 - 54                                       128         433   561
# 55 - 61                                        34         189   223
# 62 and Over                                    25          21    46
# Straight                                      224         566   790
# Gay or Lesbian                                 10          86    96
# Bisexual                                       12          24    36
# Sexual Orientation Non-Conforming               8           1     9
#
#                                         Prevalence Percent_Change
# Population
# Male                                           74%           -14%
# Female                                         25%           -44%
# Transgender                                     1%           -86%
# Gender Non-Conforming                         0.2%           N/A*
# American Indian/ Alaska Native                  0%          -100%
# Asian                                           0%           +50%
# Black/African American                         17%            -6%
# Hispanic/ Latino                               54%           -37%
# Native Hawaiian/ Other Pacific Islander       0.0%           N/A*
# White                                          23%           -22%
# Multi-Racial/Other                              6%          +500%
# Under 18                                        4%            +8%
# 18 - 24                                         7%           +91%
# 25 - 54                                        60%           -40%
# 55 - 61                                        24%           +28%
# 62 and Over                                     5%           -39%
# Straight                                       85%           N/A3
# Gay or Lesbian                                 10%           N/A3
# Bisexual                                        4%           N/A3
# Sexual Orientation Non-Conforming             1.0%           N/A3
